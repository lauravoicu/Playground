# %% [markdown]
# # Part-of-Speech Tagging
#
# Part-of-Speech Tagging (POS) Notebook.  These methods will help us computationally parse sentences and better understand words in context.
#
# For this notebook I will use Ruth Ginsberg's obituary as input (Link: https://www.legacy.com/news/celebrity-deaths/ruth-bader-ginsburg-1933-2020-influential-u-s-supreme-court-justice/)
#
# Parts of speech are the grammatical units of language — such as (in English) nouns, verbs, adjectives, adverbs, pronouns, and prepositions. Each of these parts of speech plays a different role in a sentence. By computationally identifying parts of speech, one can start computationally exploring syntax, the relationship between words — rather than only focusing on words in isolation, as in the case of tf-idf.

# %%
import spacy
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: en-core-web-sm==3.0.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.0.0/en_core_web_sm-3.0.0-py3-none-any.whl#egg=en_core_web_sm==3.0.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (3.0.0)
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from en-core-web-sm==3.0.0) (3.0.6)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (8.0.3)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.7.4)
# Requirement already satisfied: pathy>=0.3.5 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.5.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (4.48.2)
# Requirement already satisfied: numpy>=1.15.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.19.4)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.3 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.4)
# Requirement already satisfied: pydantic<1.8.0,>=1.7.1 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.7.3)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.24.0)
# Requirement already satisfied: setuptools in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (49.2.0.post20200714)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.0.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (0.8.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.1)
# Requirement already satisfied: jinja2 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.11.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.0.5)
# Requirement already satisfied: packaging>=20.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (20.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.4 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.5)
# Requirement already satisfied: smart-open<4.0.0,>=2.2.0 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (7.1.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.25.9)
# Requirement already satisfied: idna<3,>=2.5 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.1.1)
# Requirement already satisfied: six in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/laura/opt/anaconda3/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-sm==3.0.0) (2.4.7)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
PATHNAME = "ruth.txt"
text = open(PATHNAME, encoding='utf-8').read()
document = nlp(text)

# %%
#Set some display options for the visualizer
options = {"compact": True, "distance": 90, "color": "yellow", "bg": "black", "font": "Gill Sans"}

displacy.render(document, style="dep", options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="3c04db04fcdf4381b2a91f8c1169a9ca-0" class="displacy" width="70700" height="1262.0" direction="ltr" style="max-width: none; height: 1262.0px; color: yellow; background: black; font-family: Gill Sans; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ruth</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Bader</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Ginsburg</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">was</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">associate</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">justice</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">U.S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Supreme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">Court,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">second</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">woman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">Jewish</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">woman</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">appointed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">court</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">U.S.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">history.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">
#
#
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">Supreme</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">Court</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1172.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">tenure</tspan>
#     <tspan class="displacy-

# %%
for token in document:
    if token.pos_ == "NOUN":
        print(token, token.pos_)
# Out:
# justice NOUN
# woman NOUN
# woman NOUN
# court NOUN
# history NOUN
# tenure NOUN
# dissents NOUN
# longevity NOUN
# court NOUN
# rulings NOUN
# majority NOUN
# opinion NOUN
# admissions NOUN
# policy NOUN
# court NOUN
# decision NOUN
# election NOUN
# recount NOUN
# arguments NOUN
# court NOUN
# granting NOUN
# marriage NOUN
# rights NOUN
# sex NOUN
# couples NOUN
# women NOUN
# rights NOUN
# aims NOUN
# career NOUN
# women NOUN
# rights NOUN
# women NOUN
# law NOUN
# school NOUN
# class NOUN
# respect NOUN
# status NOUN
# woman NOUN
# lawyer NOUN
# law NOUN
# journal NOUN
# women NOUN
# rights NOUN
# appointment NOUN
# judge NOUN
# cases NOUN
# women NOUN
# rights NOUN
# women NOUN
# men NOUN
# appointment NOUN
# judge NOUN
# reputation NOUN
# judge NOUN
# time NOUN
# confirmation NOUN
# years NOUN
# years NOUN
# member NOUN
# court NOUN
# wing NOUN
# Cancer NOUN
# cancer NOUN
# times NOUN
# appointment NOUN
# surgery NOUN
# colon NOUN
# cancer NOUN
# chemotherapy NOUN
# radiation NOUN
# day NOUN
# bench NOUN
# cancer NOUN
# lung NOUN
# cancer NOUN
# arguments NOUN
# time NOUN
# lung NOUN
# lobectomy NOUN
# bench NOUN
# faculties NOUN
# chemotherapy NOUN
# recurrence NOUN
# cancer NOUN
# figure NOUN
# left NOUN
# years NOUN
# culture NOUN
# stardom NOUN
# moniker NOUN
# rapper NOUN
# devotion NOUN
# rights NOUN
# subject NOUN
# documentary NOUN
# RBG NOUN
# feature NOUN
# film NOUN
# Devotees NOUN
# signature NOUN
# style NOUN
# variety NOUN
# collars NOUN
# robes NOUN
# collars NOUN
# world NOUN
# majority NOUN
# opinion NOUN
# dissent NOUN
# views NOUN
# crystal NOUN
# word NOUN
# gender NOUN
# equality NOUN
# women NOUN
# people NOUN
# men NOUN
# question NOUN
# speech NOUN
# details NOUN
# repose NOUN
# visitation NOUN
# a.m. NOUN
# p.m. NOUN
# a.m. NOUN
# p.m. NOUN
# state NOUN
# woman NOUN
# person NOUN
# honor NOUN
# honor NOUN
# wool NOUN
# crepe NOUN
# seat NOUN
# bench NOUN
# front NOUN
# Courtroom NOUN
# doors NOUN
# tradition NOUN
# Tributes NOUN
# Nation NOUN
# jurist NOUN
# stature NOUN
# colleague NOUN
# Today NOUN
# confidence NOUN
# generations NOUN
# tireless NOUN
# champion NOUN
# justice NOUN
# statement NOUN

# %%
for token in document:
    if token.pos_ == "VERB":
        print(token, token.pos_)
# Out:
# appointed VERB
# Nominated VERB
# noted VERB
# wrote VERB
# stating VERB
# dissented VERB
# end VERB
# made VERB
# led VERB
# Fighting VERB
# advancing VERB
# had VERB
# fight VERB
# went VERB
# co VERB
# - VERB
# found VERB
# focus VERB
# founding VERB
# argued VERB
# including VERB
# extended VERB
# apply VERB
# served VERB
# nominated VERB
# serving VERB
# gained VERB
# held VERB
# known VERB
# fights VERB
# fought VERB
# underwent VERB
# followed VERB
# missing VERB
# followed VERB
# missed VERB
# recovering VERB
# remained VERB
# step VERB
# had VERB
# serve VERB
# announced VERB
# undergoing VERB
# became VERB
# towering VERB
# elevated VERB
# pop VERB
# referred VERB
# lifted VERB
# beloved VERB
# loved VERB
# worn VERB
# collected VERB
# had VERB
# wear VERB
# issuing VERB
# made VERB
# uttered VERB
# asked VERB
# be VERB
# say VERB
# ’d VERB
# been VERB
# raised VERB
# lie VERB
# lie VERB
# be VERB
# receive VERB
# be VERB
# draped VERB
# dating VERB
# lost VERB
# lost VERB
# mourn VERB
# remember VERB
# knew VERB

# %%
for token in document:
    print(token.text, token.pos_, token.dep_)
# Out:
# Ruth PROPN compound
# Bader PROPN compound
# Ginsburg PROPN nsubj
# was AUX ROOT
# an DET det
# associate ADJ amod
# justice NOUN attr
# of ADP prep
# the DET det
# U.S. PROPN compound
# Supreme PROPN compound
# Court PROPN pobj
# , PUNCT punct
# the DET det
# second ADJ amod
# woman NOUN appos
# and CCONJ cc
# the DET det
# first ADJ amod
# Jewish ADJ amod
# woman NOUN conj
# appointed VERB acl
# to ADP prep
# the DET det
# court NOUN pobj
# in ADP prep
# U.S. PROPN compound
# history NOUN pobj
# . PUNCT punct
#
#
#
#  SPACE nummod
# Supreme PROPN compound
# Court PROPN compound
# tenure NOUN nsubj
#
#
#  SPACE advcl
# Nominated VERB dobj
# to ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# by ADP prep
# President PROPN compound
# Bill PROPN compound
# Clinton PROPN pobj
# in ADP prep
# 1993 NUM pobj
# , PUNCT punct
# Ginsburg PROPN nsubjpass
# was AUX auxpass
# noted VERB ROOT
# for ADP prep
# her PRON poss
# liberal ADJ amod
# dissents NOUN pobj
# and CCONJ cc
# her PRON poss
# longevity NOUN conj
# on ADP prep
# the DET det
# court NOUN pobj
# . PUNCT punct
# Among ADP prep
# Ginsberg PROPN pobj
# ’s PART case
# notable ADJ amod
# rulings NOUN pobj
# were AUX ROOT
# United PROPN compound
# States PROPN nsubj
# v. ADP prep
# Virginia PROPN pobj
# ( PUNCT punct
# 1996 NUM appos
# ) PUNCT punct
# , PUNCT punct
# in ADP prep
# which DET pobj
# Ginsburg PROPN nsubj
# wrote VERB relcl
# the DET det
# majority NOUN compound
# opinion NOUN dobj
# stating VERB acl
# that SCONJ mark
# the DET det
# Virginia PROPN compound
# Military PROPN compound
# Institute PROPN poss
# ’s PART case
# all DET amod
# - PUNCT punct
# male ADJ amod
# admissions NOUN compound
# policy NOUN nsubj
# was AUX ccomp
# unconstitutional ADJ acomp
# ; PUNCT punct
# Bush PROPN poss
# v. ADP prep
# Gore PROPN pobj
# ( PUNCT punct
# 2000 NUM appos
# ) PUNCT punct
# , PUNCT punct
# in ADP prep
# which DET pobj
# she PRON nsubj
# dissented VERB relcl
# from ADP prep
# the DET det
# court NOUN poss
# ’s PART case
# decision NOUN pobj
# to PART aux
# end VERB acl
# the DET det
# presidential ADJ amod
# election NOUN compound
# recount NOUN dobj
# ; PUNCT punct
# and CCONJ cc
# Obergefell PROPN conj
# v. ADP prep
# Hodges PROPN pobj
# ( PUNCT punct
# 2015 NUM appos
# ) PUNCT punct
# , PUNCT punct
# in ADP prep
# which DET pobj
# she PRON nsubj
# made VERB relcl
# decisive ADJ amod
# arguments NOUN dobj
# that DET nsubj
# led VERB relcl
# to ADP prep
# the DET det
# court NOUN pobj
# ’s PUNCT punct
# granting NOUN conj
# of ADP prep
# marriage NOUN compound
# rights NOUN pobj
# to ADP prep
# same ADJ amod
# - PUNCT punct
# sex NOUN compound
# couples NOUN pobj
# . PUNCT punct
#
#
#  SPACE dep
# Fighting VERB pcomp
# for ADP prep
# women NOUN poss
# ’s PART case
# rights NOUN pobj
#
#
#  SPACE prep
# One NUM pobj
# of ADP prep
# the DET det
# primary ADJ amod
# aims NOUN pobj
# of ADP prep
# Ginsburg PROPN poss
# ’s PART case
# career NOUN pobj
# was AUX aux
# advancing VERB ROOT
# women NOUN poss
# ’s PART case
# rights NOUN dobj
# . PUNCT punct
# One NUM nsubj
# of ADP prep
# only ADV advmod
# nine NUM nummod
# women NOUN pobj
# in ADP prep
# a DET det
# law NOUN compound
# school NOUN compound
# class NOUN pobj
# of ADP prep
# about ADP quantmod
# 500 NUM pobj
# , PUNCT punct
# Ginsburg PROPN nsubj
# had VERB ROOT
# to PART aux
# fight VERB xcomp
# for ADP prep
# respect NOUN pobj
# and CCONJ cc
# status NOUN conj
# as ADP prep
# a DET det
# young ADJ amod
# woman NOUN compound
# lawyer NOUN pobj
# . PUNCT punct
# She PRON nsubj
# went VERB ROOT
# on ADP prt
# to PART aux
# co VERB advcl
# - VERB advcl
# found VERB conj
# the DET det
# first ADJ amod
# U.S. PROPN compound
# law NOUN compound
# journal NOUN dobj
# to PART aux
# focus VERB relcl
# on ADP prep
# women NOUN poss
# ’s PART case
# rights NOUN pobj
# , PUNCT punct
# as ADV advmod
# well ADV advmod
# as ADP cc
# co ADJ conj
# - ADJ xcomp
# founding VERB xcomp
# the DET det
# Women PROPN poss
# ’s PART case
# Rights PROPN compound
# Project PROPN dobj
# at ADP prep
# the DET det
# American PROPN compound
# Civil PROPN compound
# Liberties PROPN compound
# Union PROPN pobj
# . PUNCT punct
# Prior ADV advmod
# to ADP prep
# her PRON poss
# appointment NOUN pobj
# as ADP prep
# judge NOUN pobj
# , PUNCT punct
# she PRON nsubj
# argued VERB ROOT
# several ADJ amod
# cases NOUN dobj
# that DET nsubj
# advanced ADJ amod
# women NOUN poss
# ’s PART case
# rights NOUN relcl
# , PUNCT punct
# including VERB prep
# Reed PROPN pobj
# v. ADP prep
# Reed PROPN pobj
# ( PUNCT punct
# 1971 NUM appos
# ) PUNCT punct
# , PUNCT punct
# which DET nsubj
# extended VERB relcl
# the DET det
# Fourteenth PROPN compound
# Amendment PROPN poss
# ’s PROPN case
# Equal PROPN compound
# Protection PROPN compound
# Clause PROPN dobj
# to PART aux
# apply VERB xcomp
# to ADP prep
# women NOUN pobj
# as ADV advmod
# well ADV advmod
# as ADP cc
# men NOUN conj
# . PUNCT punct
#
#
#  SPACE dep
# U.S. PROPN compound
# Court PROPN pobj
# of ADP prep
# Appeals PROPN pobj
#
#
#  SPACE pobj
# Before ADP prep
# her PRON poss
# appointment NOUN pobj
# to ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# , PUNCT punct
# Ginsburg PROPN nsubj
# served VERB ROOT
# as ADP prep
# a DET det
# federal ADJ amod
# judge NOUN pobj
# on ADP prep
# the DET det
# U.S. PROPN compound
# Court PROPN pobj
# of ADP prep
# Appeals PROPN pobj
# , PUNCT punct
# to PART dep
# which DET pobj
# she PRON nsubjpass
# was AUX auxpass
# nominated VERB relcl
# by ADP agent
# President PROPN compound
# Jimmy PROPN compound
# Carter PROPN pobj
# in ADP prep
# 1980 NUM pobj
# . PUNCT punct
# While SCONJ mark
# serving VERB advcl
# there ADV advmod
# , PUNCT punct
# she PRON nsubj
# gained VERB ROOT
# a DET det
# reputation NOUN dobj
# as ADP prep
# a DET det
# moderate ADJ amod
# judge NOUN pobj
# , PUNCT punct
# which DET nsubj
# held VERB relcl
# true ADJ oprd
# through ADP prep
# the DET det
# time NOUN pobj
# of ADP prep
# her PRON poss
# confirmation NOUN pobj
# to ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# 13 NUM nummod
# years NOUN npadvmod
# later ADV advmod
# . PUNCT punct
# It PRON nsubj
# was AUX ROOT
# only ADV advmod
# in ADP prep
# later ADJ amod
# years NOUN pobj
# that SCONJ mark
# she PRON nsubj
# became AUX auxpass
# known VERB acomp
# as ADP prep
# a DET det
# staunch ADJ amod
# member NOUN pobj
# of ADP prep
# the DET det
# court NOUN poss
# ’s PART case
# liberal ADJ amod
# wing NOUN pobj
# . PUNCT punct
#
#
#  SPACE ROOT
# Cancer NOUN nsubj
# fights VERB ROOT
#
#
#  SPACE punct
# Ginsburg PROPN nsubj
# fought VERB ccomp
# cancer NOUN dobj
# several ADJ amod
# times NOUN npadvmod
# after ADP prep
# her PRON poss
# appointment NOUN pobj
# to ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# . PUNCT punct
# The DET det
# first ADJ nsubj
# was AUX ROOT
# in ADP prep
# 1999 NUM pobj
# , PUNCT punct
# when ADV advmod
# she PRON nsubj
# underwent VERB advcl
# surgery NOUN dobj
# for ADP prep
# colon NOUN compound
# cancer NOUN pobj
# , PUNCT punct
# followed VERB advcl
# by ADP agent
# chemotherapy NOUN pobj
# and CCONJ cc
# radiation NOUN conj
# , PUNCT punct
# without ADP prep
# missing VERB pcomp
# a DET det
# single ADJ amod
# day NOUN dobj
# on ADP prep
# the DET det
# bench NOUN pobj
# . PUNCT punct
# This DET nsubjpass
# was AUX auxpass
# followed VERB ROOT
# by ADP agent
# pancreatic ADJ amod
# cancer NOUN pobj
# in ADP prep
# 2009 NUM pobj
# and CCONJ cc
# lung NOUN compound
# cancer NOUN conj
# in ADP prep
# 2018 NUM pobj
# . PUNCT punct
# Ginsburg PROPN nsubj
# briefly ADV advmod
# missed VERB ROOT
# oral ADJ amod
# arguments NOUN dobj
# in ADP prep
# in ADP prep
# 2019 NUM pobj
# for ADP prep
# the DET det
# first ADJ amod
# time NOUN pobj
# while SCONJ mark
# recovering VERB advcl
# from ADP prep
# her PRON poss
# left ADJ amod
# - PUNCT punct
# lung NOUN compound
# lobectomy NOUN pobj
# , PUNCT punct
# though SCONJ mark
# she PRON nsubj
# remained VERB advcl
# determined ADJ acomp
# not PART neg
# to PART aux
# step VERB xcomp
# down ADP prt
# from ADP prep
# the DET det
# bench NOUN pobj
# while SCONJ mark
# she PRON nsubj
# still ADV advmod
# had VERB advcl
# the DET det
# mental ADJ amod
# faculties NOUN nsubj
# to PART aux
# serve VERB ccomp
# . PUNCT punct
# In ADP prep
# July PROPN pobj
# 2020 NUM nummod
# , PUNCT punct
# Ginsburg PROPN nsubj
# announced VERB ROOT
# she PRON nsubj
# was AUX aux
# undergoing VERB ccomp
# chemotherapy NOUN dobj
# for ADP prep
# a DET det
# recurrence NOUN pobj
# of ADP prep
# cancer NOUN pobj
# . PUNCT punct
#
#
#  SPACE ROOT
# The DET det
# Notorious PROPN compound
# R.B.G. PROPN nsubj
#
#
#  SPACE nsubj
# Ginsburg PROPN pobj
# became VERB ROOT
# a DET det
# towering VERB amod
# figure NOUN attr
# of ADP prep
# the DET det
# political ADJ amod
# left NOUN pobj
# in ADP prep
# later ADJ amod
# years NOUN pobj
# , PUNCT punct
# elevated VERB advcl
# to PART aux
# pop VERB xcomp
# culture NOUN compound
# stardom NOUN dobj
# and CCONJ cc
# referred VERB conj
# to ADP prep
# as ADP prep
# “ PUNCT punct
# The DET det
# Notorious PROPN compound
# R.B.G. PROPN pobj
# , PUNCT punct
# ” PUNCT punct
# a DET det
# moniker NOUN appos
# lifted VERB acl
# from ADP prep
# rapper NOUN pobj
# The DET det
# Notorious PROPN compound
# B.I.G. PROPN appos
# She PRON nsubjpass
# was AUX auxpass
# beloved VERB ROOT
# for ADP prep
# her PRON poss
# fiery ADJ amod
# devotion NOUN pobj
# to ADP prep
# human ADJ amod
# rights NOUN pobj
# , PUNCT punct
# the DET det
# subject NOUN appos
# of ADP prep
# documentary NOUN nmod
# “ PUNCT punct
# RBG NOUN pobj
# ” PUNCT punct
# and CCONJ cc
# feature NOUN compound
# film NOUN conj
# “ PUNCT punct
# On ADP prep
# the DET det
# Basis PROPN pobj
# of ADP prep
# Sex PROPN pobj
# . PUNCT punct
# ” PUNCT punct
# Devotees NOUN nsubj
# also ADV advmod
# loved VERB ROOT
# Ginsburg PROPN dobj
# for ADP prep
# her PRON poss
# signature NOUN compound
# style NOUN pobj
# of ADP prep
# a DET det
# wide ADJ amod
# variety NOUN pobj
# of ADP prep
# decorative ADJ amod
# collars NOUN pobj
# worn VERB acl
# with ADP prep
# her PRON poss
# judicial ADJ amod
# robes NOUN pobj
# . PUNCT punct
# She PRON nsubj
# collected VERB ROOT
# collars NOUN dobj
# from ADP prep
# around ADP prep
# the DET det
# world NOUN pobj
# and CCONJ cc
# had VERB conj
# a DET det
# favorite ADJ dobj
# to PART aux
# wear VERB relcl
# when ADV advmod
# issuing VERB advcl
# a DET det
# majority NOUN compound
# opinion NOUN dobj
# and CCONJ cc
# another DET conj
# for ADP prep
# a DET det
# dissent NOUN pobj
# , PUNCT punct
# which DET nsubj
# made VERB relcl
# her PRON poss
# views NOUN nsubj
# crystal NOUN nsubj
# clear ADJ ccomp
# before ADP mark
# she PRON nsubj
# ever ADV advmod
# uttered VERB advcl
# a DET det
# word NOUN dobj
# . PUNCT punct
#
#
#  SPACE ROOT
# Ginsburg PROPN nsubj
# on ADP prep
# gender NOUN compound
# equality NOUN pobj
#
#
#  SPACE ROOT
# “ PUNCT punct
# [ PUNCT punct
# W]hen ADV advmod
# I PRON nsubjpass
# ’m AUX auxpass
# sometimes ADV advmod
# asked VERB ccomp
# when ADV advmod
# there PRON expl
# will AUX aux
# be VERB ccomp
# enough ADJ acomp
# [ PUNCT punct
# women NOUN npadvmod
# on ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# ] PUNCT punct
# and CCONJ cc
# I PRON nsubj
# say VERB conj
# ‘ PUNCT punct
# When ADV advmod
# there PRON expl
# are AUX ccomp
# nine NUM attr
# , PUNCT punct
# ’ PUNCT punct
# people NOUN nsubj
# are AUX ccomp
# shocked ADJ acomp
# . PUNCT punct
# But CCONJ cc
# there PRON expl
# ’d VERB neg
# been VERB ROOT
# nine NUM nummod
# men NOUN attr
# , PUNCT punct
# and CCONJ cc
# nobody PRON nsubj
# ’s AUX auxpass
# ever ADV advmod
# raised VERB conj
# a DET det
# question NOUN dobj
# about ADP prep
# that DET pobj
# . PUNCT punct
# ” PUNCT punct
# — PUNCT punct
# from ADP prep
# a DET det
# speech NOUN pobj
# at ADP prep
# the DET det
# 10th ADJ amod
# Circuit PROPN compound
# Bench PROPN nmod
# & CCONJ cc
# Bar PROPN conj
# Conference PROPN pobj
# in ADP prep
# 2012 NUM pobj
#
#
#  SPACE dep
# Funeral ADJ compound
# details NOUN nsubj
#
#
#  SPACE prep
# Ginsburg PROPN pobj
# will AUX aux
# lie VERB conj
# in ADP prep
# repose NOUN pobj
# at ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# on ADP prep
# Wednesday PROPN pobj
# and CCONJ cc
# Thursday PROPN conj
# , PUNCT punct
# September PROPN appos
# 23 NUM nummod
# and CCONJ cc
# 24 NUM conj
# , PUNCT punct
# with ADP prep
# public ADJ amod
# visitation NOUN nsubj
# available ADJ pcomp
# from ADP prep
# 11 NUM nummod
# a.m. NOUN pobj
# to ADP prep
# 10 NUM nummod
# p.m. NOUN pobj
# on ADP prep
# Wednesday PROPN pobj
# and CCONJ cc
# 9 NUM nummod
# a.m. NOUN conj
# to ADP prep
# 10 NUM nummod
# p.m. NOUN pobj
# on ADP prep
# Thursday PROPN pobj
# . PUNCT punct
# On ADP prep
# Friday PROPN pobj
# , PUNCT punct
# September PROPN npadvmod
# 25 NUM nummod
# , PUNCT punct
# Ginsburg PROPN nsubj
# will AUX aux
# lie VERB ROOT
# in ADP prep
# state NOUN pobj
# in ADP prep
# the DET det
# National PROPN compound
# Statuary PROPN compound
# Hall PROPN pobj
# in ADP prep
# the DET det
# U.S. PROPN compound
# Capitol PROPN pobj
# . PUNCT punct
# She PRON nsubj
# will AUX aux
# be VERB ROOT
# the DET det
# first ADJ amod
# woman NOUN attr
# and CCONJ cc
# the DET det
# first ADJ amod
# Jewish ADJ amod
# person NOUN conj
# to PART aux
# receive VERB relcl
# this DET det
# honor NOUN dobj
# . PUNCT punct
# Interment PROPN nsubj
# will AUX aux
# be VERB ROOT
# private ADJ acomp
# at ADP prep
# Arlington PROPN compound
# National PROPN compound
# Cemetery PROPN pobj
# . PUNCT punct
# In ADP prep
# Ginsburg PROPN poss
# ’s PART case
# honor NOUN pobj
# , PUNCT punct
# the DET det
# Supreme PROPN compound
# Court PROPN nsubj
# has AUX aux
# draped VERB ROOT
# black ADJ amod
# wool NOUN compound
# crepe NOUN dobj
# on ADP prep
# her PRON poss
# seat NOUN pobj
# , PUNCT punct
# the DET det
# bench NOUN appos
# in ADP prep
# front NOUN pobj
# of ADP prep
# it PRON pobj
# , PUNCT punct
# and CCONJ cc
# the DET det
# Courtroom NOUN compound
# doors NOUN conj
# , PUNCT punct
# in ADP prep
# a DET det
# tradition NOUN pobj
# dating VERB acl
# back ADV advmod
# to ADP prep
# 1873 NUM pobj
# . PUNCT punct
#
#
#  SPACE ROOT
# Tributes NOUN pobj
# to ADP prep
# Justice PROPN compound
# Ginsburg PROPN pobj
#
#
#  SPACE prep
# “ PUNCT punct
# Our PRON poss
# Nation NOUN nsubj
# has AUX aux
# lost VERB ccomp
# a DET det
# jurist NOUN dobj
# of ADP prep
# historic ADJ amod
# stature NOUN pobj
# . PUNCT punct
# We PRON nsubj
# at ADP prep
# the DET det
# Supreme PROPN compound
# Court PROPN pobj
# have AUX aux
# lost VERB ROOT
# a DET det
# cherished ADJ amod
# colleague NOUN dobj
# . PUNCT punct
# Today NOUN npadvmod
# we PRON nsubj
# mourn VERB ROOT
# , PUNCT punct
# but CCONJ cc
# with ADP conj
# confidence NOUN pobj
# that SCONJ mark
# future ADJ amod
# generations NOUN nsubj
# will AUX aux
# remember VERB acl
# Ruth PROPN compound
# Bader PROPN compound
# Ginsburg PROPN dobj
# as ADP mark
# we PRON nsubj
# knew VERB advcl
# her PRON dobj
# — PUNCT punct
# a DET det
# tireless NOUN nmod
# and CCONJ cc
# resolute ADJ conj
# champion NOUN appos
# of ADP prep
# justice NOUN pobj
# . PUNCT punct
# ” PUNCT punct
# — PUNCT punct
# Supreme PROPN compound
# Court PROPN compound
# Chief PROPN compound
# Justice PROPN compound
# John PROPN compound
# G. PROPN compound
# Roberts PROPN ROOT
# , PUNCT punct
# in ADP prep
# a DET det
# statement NOUN pobj
# . PUNCT punct

# %%
adjs = []
for token in document:
    if token.pos_ == 'ADJ':
        adjs.append(token.text)
        
adjs
# Out:
# ['associate',
#  'second',
#  'first',
#  'Jewish',
#  'liberal',
#  'notable',
#  'male',
#  'unconstitutional',
#  'presidential',
#  'decisive',
#  'same',
#  'primary',
#  'young',
#  'first',
#  'co',
#  '-',
#  'several',
#  'advanced',
#  'federal',
#  'moderate',
#  'true',
#  'later',
#  'staunch',
#  'liberal',
#  'several',
#  'first',
#  'single',
#  'pancreatic',
#  'oral',
#  'first',
#  'left',
#  'determined',
#  'mental',
#  'political',
#  'later',
#  'fiery',
#  'human',
#  'wide',
#  'decorative',
#  'judicial',
#  'favorite',
#  'clear',
#  'enough',
#  'shocked',
#  '10th',
#  'Funeral',
#  'public',
#  'available',
#  'first',
#  'first',
#  'Jewish',
#  'private',
#  'black',
#  'historic',
#  'cherished',
#  'future',
#  'resolute']

# %%
adjs_tally = Counter(adjs)

# %%
adjs_tally.most_common()
# Out:
# [('first', 6),
#  ('Jewish', 2),
#  ('liberal', 2),
#  ('several', 2),
#  ('later', 2),
#  ('associate', 1),
#  ('second', 1),
#  ('notable', 1),
#  ('male', 1),
#  ('unconstitutional', 1),
#  ('presidential', 1),
#  ('decisive', 1),
#  ('same', 1),
#  ('primary', 1),
#  ('young', 1),
#  ('co', 1),
#  ('-', 1),
#  ('advanced', 1),
#  ('federal', 1),
#  ('moderate', 1),
#  ('true', 1),
#  ('staunch', 1),
#  ('single', 1),
#  ('pancreatic', 1),
#  ('oral', 1),
#  ('left', 1),
#  ('determined', 1),
#  ('mental', 1),
#  ('political', 1),
#  ('fiery', 1),
#  ('human', 1),
#  ('wide', 1),
#  ('decorative', 1),
#  ('judicial', 1),
#  ('favorite', 1),
#  ('clear', 1),
#  ('enough', 1),
#  ('shocked', 1),
#  ('10th', 1),
#  ('Funeral', 1),
#  ('public', 1),
#  ('available', 1),
#  ('private', 1),
#  ('black', 1),
#  ('historic', 1),
#  ('cherished', 1),
#  ('future', 1),
#  ('resolute', 1)]

# %%
df = pd.DataFrame(adjs_tally.most_common(), columns=['adj', 'count'])
df[:100]
# Out:
#                  adj  count
# 0              first      6
# 1             Jewish      2
# 2            liberal      2
# 3            several      2
# 4              later      2
# 5          associate      1
# 6             second      1
# 7            notable      1
# 8               male      1
# 9   unconstitutional      1
# 10      presidential      1
# 11          decisive      1
# 12              same      1
# 13           primary      1
# 14             young      1
# 15                co      1
# 16                 -      1
# 17          advanced      1
# 18           federal      1
# 19          moderate      1
# 20              true      1
# 21           staunch      1
# 22            single      1
# 23        pancreatic      1
# 24              oral      1
# 25              left      1
# 26        determined      1
# 27            mental      1
# 28         political      1
# 29             fiery      1
# 30             human      1
# 31              wide      1
# 32        decorative      1
# 33          judicial      1
# 34          favorite      1
# 35             clear      1
# 36            enough      1
# 37           shocked      1
# 38              10th      1
# 39           Funeral      1
# 40            public      1
# 41         available      1
# 42           private      1
# 43             black      1
# 44          historic      1
# 45         cherished      1
# 46            future      1
# 47          resolute      1

# %%
nouns = []
for token in document:
    if token.pos_ == 'NOUN':
        nouns.append(token.text)

nouns_tally = Counter(nouns)

df = pd.DataFrame(nouns_tally.most_common(), columns=['noun', 'count'])
df[:100]
# Out:
#             noun  count
# 0          women      7
# 1         rights      6
# 2          court      5
# 3         cancer      5
# 4          woman      4
# 5    appointment      3
# 6          judge      3
# 7          years      3
# 8          bench      3
# 9        justice      2
# 10      majority      2
# 11       opinion      2
# 12     arguments      2
# 13           law      2
# 14           men      2
# 15          time      2
# 16  chemotherapy      2
# 17          lung      2
# 18       collars      2
# 19          a.m.      2
# 20          p.m.      2
# 21         honor      2
# 22       history      1
# 23        tenure      1
# 24      dissents      1
# 25     longevity      1
# 26       rulings      1
# 27    admissions      1
# 28        policy      1
# 29      decision      1
# 30      election      1
# 31       recount      1
# 32      granting      1
# 33      marriage      1
# 34           sex      1
# 35       couples      1
# 36          aims      1
# 37        career      1
# 38        school      1
# 39         class      1
# 40       respect      1
# 41        status      1
# 42        lawyer      1
# 43       journal      1
# 44         cases      1
# 45    reputation      1
# 46  confirmation      1
# 47        member      1
# 48          wing      1
# 49        Cancer      1
# 50         times      1
# 51       surgery      1
# 52         colon      1
# 53     radiation      1
# 54           day      1
# 55     lobectomy      1
# 56     faculties      1
# 57    recurrence      1
# 58        figure      1
# 59          left      1
# 60       culture      1
# 61       stardom      1
# 62       moniker      1
# 63        rapper      1
# 64      devotion      1
# 65       subject      1
# 66   documentary      1
# 67           RBG      1
# 68       feature      1
# 69          film      1
# 70      Devotees      1
# 71     signature      1
# 72         style      1
# 73       variety      1
# 74         robes      1
# 75         world      1
# 76       dissent      1
# 77         views      1
# 78       crystal      1
# 79          word      1
# 80        gender      1
# 81      equality      1
# 82        people      1
# 83      question      1
# 84        speech      1
# 85       details      1
# 86        repose      1
# 87    visitation      1
# 88         state      1
# 89        person      1
# 90          wool      1
# 91         crepe      1
# 92          seat      1
# 93         front      1
# 94     Courtroom      1
# 95         doors      1
# 96     tradition      1
# 97      Tributes      1
# 98        Nation      1
# 99        jurist      1

# %%
verbs = [token.text for token in document if token.pos_ == 'VERB']

verbs_tally = Counter(verbs)

df = pd.DataFrame(verbs_tally.most_common(), columns=['verb', 'count'])
df[:100]
# Out:
#           verb  count
# 0          had      3
# 1           be      3
# 2         made      2
# 3     followed      2
# 4          lie      2
# 5         lost      2
# 6    appointed      1
# 7    Nominated      1
# 8        noted      1
# 9        wrote      1
# 10     stating      1
# 11   dissented      1
# 12         end      1
# 13         led      1
# 14    Fighting      1
# 15   advancing      1
# 16       fight      1
# 17        went      1
# 18          co      1
# 19           -      1
# 20       found      1
# 21       focus      1
# 22    founding      1
# 23      argued      1
# 24   including      1
# 25    extended      1
# 26       apply      1
# 27      served      1
# 28   nominated      1
# 29     serving      1
# 30      gained      1
# 31        held      1
# 32       known      1
# 33      fights      1
# 34      fought      1
# 35   underwent      1
# 36     missing      1
# 37      missed      1
# 38  recovering      1
# 39    remained      1
# 40        step      1
# 41       serve      1
# 42   announced      1
# 43  undergoing      1
# 44      became      1
# 45    towering      1
# 46    elevated      1
# 47         pop      1
# 48    referred      1
# 49      lifted      1
# 50     beloved      1
# 51       loved      1
# 52        worn      1
# 53   collected      1
# 54        wear      1
# 55     issuing      1
# 56     uttered      1
# 57       asked      1
# 58         say      1
# 59          ’d      1
# 60        been      1
# 61      raised      1
# 62     receive      1
# 63      draped      1
# 64      dating      1
# 65       mourn      1
# 66    remember      1
# 67        knew      1

# %%
import re
from IPython.display import Markdown, display

# %%
def find_sentences_with_keyword(keyword, document):
    
    #Iterate through all the sentences in the document and pull out the text of each sentence
    for sentence in document.sents:
        sentence = sentence.text
        
        #Check to see if the keyword is in the sentence (and ignore capitalization by making both lowercase)
        if keyword.lower() in sentence.lower():
            
            #Use the regex library to replace linebreaks and to make the keyword bolded, again ignoring capitalization
            sentence = re.sub('\n', ' ', sentence)
            sentence = re.sub(f"{keyword}", f"**{keyword}**", sentence, flags=re.IGNORECASE)
            
            display(Markdown(sentence))

# %%
find_sentences_with_keyword(keyword="liberal", document=document)
# Out:
#    Supreme Court tenure  Nominated to the Supreme Court by President Bill Clinton in 1993, Ginsburg was noted for her **liberal** dissents and her longevity on the court.
# It was only in later years that she became known as a staunch member of the court’s **liberal** wing.

# %%
#Make a list of tokens and POS labels from document if the token is a word 
tokens_and_labels = [(token.text, token.pos_) for token in document if token.is_alpha]

# %%
#Make a function to get all two-word combinations
def get_bigrams(word_list, number_consecutive_words=2):
    
    ngrams = []
    adj_length_of_word_list = len(word_list) - (number_consecutive_words - 1)
    
    #Loop through numbers from 0 to the (slightly adjusted) length of your word list
    for word_index in range(adj_length_of_word_list):
        
        #Index the list at each number, grabbing the word at that number index as well as N number of words after it
        ngram = word_list[word_index : word_index + number_consecutive_words]
        
        #Append this word combo to the master list "ngrams"
        ngrams.append(ngram)
        
    return ngrams

# %%
bigrams = get_bigrams(tokens_and_labels)

# %%
bigrams[5:20]
# Out:
# [[('associate', 'ADJ'), ('justice', 'NOUN')],
#  [('justice', 'NOUN'), ('of', 'ADP')],
#  [('of', 'ADP'), ('the', 'DET')],
#  [('the', 'DET'), ('Supreme', 'PROPN')],
#  [('Supreme', 'PROPN'), ('Court', 'PROPN')],
#  [('Court', 'PROPN'), ('the', 'DET')],
#  [('the', 'DET'), ('second', 'ADJ')],
#  [('second', 'ADJ'), ('woman', 'NOUN')],
#  [('woman', 'NOUN'), ('and', 'CCONJ')],
#  [('and', 'CCONJ'), ('the', 'DET')],
#  [('the', 'DET'), ('first', 'ADJ')],
#  [('first', 'ADJ'), ('Jewish', 'ADJ')],
#  [('Jewish', 'ADJ'), ('woman', 'NOUN')],
#  [('woman', 'NOUN'), ('appointed', 'VERB')],
#  [('appointed', 'VERB'), ('to', 'ADP')]]

# %%
def get_neighbor_words(keyword, bigrams, pos_label = None):
    
    neighbor_words = []
    keyword = keyword.lower()
    
    for bigram in bigrams:
        
        #Extract just the lowercased words (not the labels) for each bigram
        words = [word.lower() for word, label in bigram]        
        
        #Check to see if keyword is in the bigram
        if keyword in words:
            
            for word, label in bigram:
                
                #Now focus on the neighbor word, not the keyword
                if word.lower() != keyword:
                    #If the neighbor word matches the right pos_label, append it to the master list
                    if label == pos_label or pos_label == None:
                        neighbor_words.append(word.lower())
    
    return Counter(neighbor_words).most_common()

# %%
get_neighbor_words("liberal", bigrams)
# Out:
# [('her', 1), ('dissents', 1), ('court', 1), ('wing', 1)]

# %%
get_neighbor_words("liberal", bigrams, pos_label='NOUN')
# Out:
# [('dissents', 1), ('court', 1), ('wing', 1)]
